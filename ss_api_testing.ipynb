# %% [markdown]
# <a href="https://colab.research.google.com/github/zaphodnothingth/graph2/blob/main/ss_api_testing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
import pandas as pd

# %%
ssAPIkey = 'qZWKkOKyzP5g9fgjyMmBt1MN2NTC6aT61UklAiyw' # approved for 100 req/sec
ssBASE = 'http://api.semanticscholar.org/graph/v1/paper/'

search_terms = '"data science" or "machine learning"'
ssENDPOINTsearch = f'''search?
                     year%5B0%5D=2011&year%5B1%5D=2012 \
                     &query={search_terms}&offset=10&limit=50&fields=title,authors,year'''

# %%
headers = {'x-api-key': ssAPIkey}

# %%
resp = requests.get(ssBASE + ssENDPOINTsearch, headers=headers)
print(resp.content)
df = pd.DataFrame(resp.json()['data'])
# Out:
# b'{"total": 15169, "offset": 10, "next": 60, "data": [{"paperId": "f7a3199da31504a23b0a59e4186ea4d98ed7276e", "title": "Data science and machine learning in anesthesiology", "year": 2020, "authors": [{"authorId": "14287189", "name": "Dongwoo Chae"}]}, {"paperId": "760cc16e1cd1239714a1d4fd872e0ea268c1a992", "title": "Machine Learning meets Number Theory: The Data Science of Birch-Swinnerton-Dyer", "year": 2019, "authors": [{"authorId": "2818774", "name": "Laura Alessandretti"}, {"authorId": "2836702", "name": "A. Baronchelli"}, {"authorId": "2022419", "name": "Yang-Hui He"}]}, {"paperId": "bb44d1472bb281c699ef556f6eb6ccc66889f2d3", "title": "Data Science and Machine Learning", "year": 2019, "authors": [{"authorId": "1704242", "name": "Dirk P. Kroese"}, {"authorId": "1929279", "name": "Z. Botev"}, {"authorId": "1997850", "name": "T. Taimre"}, {"authorId": "2168267", "name": "Radislav Vaisman"}]}, {"paperId": "13e5ca3313164aeb0adce94d12ff522d162505b0", "title": "Introduction to Data Sci
# ...

# %%
df
# Out:
#                                      paperId  ...                                            authors
# 0   f7a3199da31504a23b0a59e4186ea4d98ed7276e  ...  [{'authorId': '14287189', 'name': 'Dongwoo Cha...
# 1   760cc16e1cd1239714a1d4fd872e0ea268c1a992  ...  [{'authorId': '2818774', 'name': 'Laura Alessa...
# 2   bb44d1472bb281c699ef556f6eb6ccc66889f2d3  ...  [{'authorId': '1704242', 'name': 'Dirk P. Kroe...
# 3   13e5ca3313164aeb0adce94d12ff522d162505b0  ...  [{'authorId': '98028619', 'name': 'K. Sud'}, {...
# 4   958f5b94748d1494238d10ec0279edf11843acf9  ...   [{'authorId': '2005636086', 'name': 'S. Islam'}]
# 5   f2e79452aef17bc27ceb72aa9382db74c0fe827b  ...    [{'authorId': '2562040', 'name': 'S. Raschka'}]
# 6   9f119f4a20327e8ad17325a88f44ff3964ef4411  ...  [{'authorId': '104146625', 'name': 'Trang T. L...
# 7   e8547557eeea9c9a334edfc4bfa4bbe3774e24d5  ...   [{'authorId': '2424441', 'name': 'A. Ferguson'}]
# ...

# %%
resp.json()
# Out:
# {'data': [{'authors': [{'authorId': '14287189', 'name': 'Dongwoo Chae'}],
#    'paperId': 'f7a3199da31504a23b0a59e4186ea4d98ed7276e',
#    'title': 'Data science and machine learning in anesthesiology',
#    'year': 2020},
#   {'authors': [{'authorId': '2818774', 'name': 'Laura Alessandretti'},
#     {'authorId': '2836702', 'name': 'A. Baronchelli'},
#     {'authorId': '2022419', 'name': 'Yang-Hui He'}],
#    'paperId': '760cc16e1cd1239714a1d4fd872e0ea268c1a992',
#    'title': 'Machine Learning meets Number Theory: The Data Science of Birch-Swinnerton-Dyer',
#    'year': 2019},
#   {'authors': [{'authorId': '1704242', 'name': 'Dirk P. Kroese'},
#     {'authorId': '1929279', 'name': 'Z. Botev'},
#     {'authorId': '1997850', 'name': 'T. Taimre'},
#     {'authorId': '2168267', 'name': 'Radislav Vaisman'}],
#    'paperId': 'bb44d1472bb281c699ef556f6eb6ccc66889f2d3',
#    'title': 'Data Science and Machine Learning',
#    'year': 2019},
# ...
